# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = "C:/Users/ivi/Desktop/Challenge 1 Vision/Frontal/Frontal/1062FNT.jpg"
im = cv2.imread(image_path)
HASAN_KARAN_TRANSFORMATION_COEFFS = [0.114, 0.587, 0.299] #Special Grayscale Transformation
m = np.array(HASAN_KARAN_TRANSFORMATION_COEFFS).reshape((1,3))
grayscale_image = cv2.transform(im, m)

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(im)
ax2.imshow(grayscale_image, cmap= 'gray')

# %%
median_image = cv2.medianBlur(grayscale_image, 3)

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(grayscale_image, cmap= 'gray')
ax2.imshow(median_image, cmap= 'gray')

# %%
ret2,binary_image = cv2.threshold(median_image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(median_image, cmap= 'gray')
ax2.imshow(binary_image, cmap= 'gray')

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (60, 60))
blackhat_im = cv2.morphologyEx(grayscale_image, cv2.MORPH_BLACKHAT, kernel)

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(grayscale_image,  cmap = 'gray')
ax2.imshow(blackhat_im, cmap = 'gray')

# %%
#BINARIZE AFTER DOING BLACKHAT

ret2,binary_image_hat = cv2.threshold(blackhat_im,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(grayscale_image, cmap= 'gray')
ax2.imshow(binary_image_hat, cmap= 'gray')

# %%
kernel = np.ones((5, 5), np.uint8) 
img_erosion = cv2.erode(binary_image_hat, kernel, iterations=2) 


fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(binary_image_hat, cmap= 'gray')
ax2.imshow(img_erosion, cmap= 'gray')

# %%
opening = cv2.morphologyEx(img_erosion, cv2.MORPH_OPEN, kernel)
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(12, 6))
ax1.imshow(img_erosion, cmap= 'gray')
ax2.imshow(opening, cmap= 'gray')
